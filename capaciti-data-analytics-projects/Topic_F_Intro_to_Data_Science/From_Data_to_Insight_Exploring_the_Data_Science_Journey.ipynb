# %% [markdown]
# # From Data to Insight: Exploring the Data Science Journey
# #### 👩🏽‍💻
# In this notebook, we explain what data science is and walk through the key steps in the **Data Science Process**:
#
# 1. Collect
# 2. Clean
# 3. Analyze
# 4. Visualize
# 5. Interpret
#
# We'll also explain how **programming** is used in each step.

# %% [markdown]
# ## 🧠 What is Data Science?
#
# Data Science is a field that combines programming, mathematics, and domain knowledge to extract insights from data.
#
# It is used in business, healthcare, finance, education, and many other fields to make data-driven decisions.

# %% [markdown]
# ## 🔄 The Data Science Process Flowchart
#
# Below is a visual representation of the Data Science process.

# %%
from IPython.display import Image
Image('data_science_flowchart.jpeg')

# %% [markdown]
# ## 💻 How Programming Helps in Each Step
#
# **1. Collect**
# Using Python, we can:
# - Use APIs to gather data
# - Read files like CSV, Excel, JSON
#
# **2. Clean**
# With libraries like `pandas`, we can:
# - Remove missing data
# - Fix inconsistent values
# - Convert data types
#
# **3. Analyze**
# Programming helps to:
# - Calculate statistics (mean, median, etc.)
# - Group and compare data
#
# **4. Visualize**
# Libraries like `matplotlib` and `seaborn` help to:
# - Plot charts (bar, line, scatter, etc.)
# - Understand trends and patterns visually
#
# **5. Interpret**
# Code helps to:
# - Write reports
# - Create dashboards
# - Automate insights

# %% [markdown]
# ## 📝 Final Summary
#
# - Data science is a step-by-step process.
# - Programming is the main tool used to move through each step efficiently.
# - Python makes it easy to collect, clean, analyze, visualize, and interpret data.
#
# 🎯 Next, we will start working on real data using pandas in the upcoming Topic G!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
